# %% [markdown]
# # RepairMate
#
# # Use Case Justification –
#
# ## Chosen Use Case: Mobile Repair Support Chatbot
# **RepairMate** is a conversational chatbot that guides users through common mobile phone issues, troubleshooting steps, and repair service options.
#
# ---
#
# ## Target Users
# - Smartphone users facing technical problems (e.g., slow performance, battery drain, connectivity issues)
# - People who want **quick help** before visiting a repair shop
#
# ---
#
# ## Expected Benefits
# - Provides **instant troubleshooting** for common problems
# - Reduces dependency on in-person visits for small issues
# - Saves **time** for both customers and repair technicians
# - Works **24/7** as a first line of support
#
# ---
#
# ## Limitations
# - Cannot physically repair devices
# - May not cover rare or **hardware-specific** issues
# - Suggestions are **general guidance**, not a substitute for professional diagnosis
#
# ---
#
# ##  Why This Problem is Worth Solving
# - Many users visit repair shops for **minor, fixable issues** (like cache clearing, app crashes, or misconfigured settings).
# - A chatbot can **filter cases** → only send users to repair shops when really necessary.
# - Saves **costs for businesses** by reducing repetitive inquiries.
#
# ---
#
# ##  Why `meta-llama/llama-4-scout-17b-16e-instruct` Fits
# - **Instruction Following** → Perfect for troubleshooting-style steps
# - **Reasoning Power** → Can handle diagnostic Q&A before suggesting fixes
# - **Balanced Size (17B)** → Smart enough for repair logic, still fast on Groq hardware
# - **Conversational Tone** → Friendly and helpful, ideal for customer support
#
# ---
#
# # 📌 Conversational Flow – Sample Dialogues
#
# ---
#
# ### 👋 Greeting
# **User:** Hi
# **RepairMate:** Hello 👋 I’m RepairMate, your mobile repair assistant. What issue are you facing with your phone today?
#
# ---
#
# ### Scenario 1 – Battery Issue
# **User:** My phone battery drains too fast.
# **RepairMate:** Sorry to hear that ⚡ Let’s try a few quick checks:
#
# 1. Do you have a lot of apps running in the background?
# 2. Is your screen brightness set very high?
# 3. How old is your phone’s battery?
#
# ➡️ If the user confirms an easy fix:
# **RepairMate:** Try lowering brightness and closing unused apps. Also, check if battery saver mode is enabled.
#
# ➡️ If it seems hardware-related:
# **RepairMate:** It looks like your battery might be worn out. I recommend visiting a repair center for a replacement. Would you like me to suggest a nearby service center?
#
# ---
#
# ### 📱 Scenario 2 – Screen Problem
# **User:** My screen is cracked.
# **RepairMate:** That sounds frustrating Unfortunately, a cracked screen usually requires a replacement. I can help you:
#
# - Find the nearest repair shop
# - Estimate the cost for screen replacement
#
# Would you like me to check that for your phone model?
#
# ---
#
# ### ❓ Scenario 3 – Unknown Problem (Fallback)
# **User:** My phone keeps buzzing randomly.
# **RepairMate:** Hmm I don’t have a direct solution for that yet. Could you describe when it happens (e.g., while charging, during calls, or while idle)?
#
# ---
#
# ### 👋 Goodbye
# **User:** Thanks, that’s all I needed.
# **RepairMate:** You’re welcome I’m here anytime you need help with your phone. Stay safe and take care!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
